# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrishna1108/5106_Final_Project/blob/main/Transformer_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/saikrishna1108/5106_Final_Project.git
# Out:
# Cloning into '5106_Final_Project'...
# remote: Enumerating objects: 813, done.
# remote: Counting objects: 100% (689/689), done.
# remote: Compressing objects: 100% (667/667), done.
# remote: Total 813 (delta 89), reused 527 (delta 21), pack-reused 124
# Receiving objects: 100% (813/813), 4.02 MiB | 15.01 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# Updating files: 100% (651/651), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/rtml/5106_Final_Project/5106_Final_Project')

# %%
import os
import torch
import numpy as np
import random
from torch.utils.data import DataLoader, Dataset
import math

class SpeedDataset(Dataset):
    def __init__(self, directory, sequence_length=5, augment=True):
        self.data = []
        self.sequence_length = sequence_length
        # self.num_classes = (105 - 30) // 10 + 1  # Speed classes from 30-39, ..., 100-105
        self.augment = augment  # Enable or disable augmentation
        self.preprocess_data(directory)
        self.normalize_features()

    def preprocess_data(self, directory):
        for filename in os.listdir(directory):
            if filename.endswith('.txt'):
                speed = float(filename.split('_')[-1].replace('.txt', ''))
                # speed_class = 0 if speed < 30 else (int(speed) - 30) // 10
                filepath = os.path.join(directory, filename)
                with open(filepath, 'r') as file:
                    track_data = {}
                    for line in file:
                        points = line.strip().split(',')
                        if len(points) == 6:
                            frame, track_id, x1, y1, x2, y2 = map(float, line.strip().split(','))
                        if len(points) == 7:
                            frame,class_id, track_id, x1, y1, x2, y2 = map(float, line.strip().split(','))
                        if track_id not in track_data:
                            track_data[track_id] = []
                        track_data[track_id].append([x1, y1, x2, y2])

                    for track_id, frames in track_data.items():
                        if len(frames) >= self.sequence_length:
                            features = self.extract_features(frames)
                            overlap = 5  # Overlap for sequence extraction
                            for start_idx in range(0, len(features) - self.sequence_length + 1, self.sequence_length - overlap):
                                end_idx = start_idx + self.sequence_length
                                sequence = features[start_idx:end_idx]
                                self.data.append((sequence, speed))

    def extract_features(self, frames):
        features = []
        for i in range(1, len(frames)):
            current_frame = frames[i]
            previous_frame = frames[i-1]
            features.append(self.compute_frame_features(current_frame, previous_frame))
        return features

    def compute_frame_features(self, current_frame, previous_frame):
        x1, y1, x2, y2 = current_frame
        px1, py1, px2, py2 = previous_frame

        width, height = x2 - x1, y2 - y1
        p_width, p_height = px2 - px1, py2 - py1

        x2_change = x2 - px2
        y2_change = y2 - py2
        x1_change = x1 - px1
        y1_change = y1 - py1

        width_change = width - p_width
        height_change = height - p_height
        area_change = (width * height) - (p_width * p_height)
        perimeter_change = (2 * (width + height)) - (2 * (p_width + p_height))

        center_x, center_y = (x1 + x2) / 2, (y1 + y2) / 2
        p_center_x, p_center_y = (px1 + px2) / 2, (py1 + py2) / 2
        center_x_change = center_x - p_center_x
        center_y_change = center_y - p_center_y
        distance_moved = math.sqrt(center_x_change ** 2 + center_y_change ** 2)

        velocity = distance_moved/0.03  # Assuming constant frame rate
        p_velocity = (math.sqrt((px2 - px1) ** 2 + (py2 - py1) ** 2))/0.03
        acceleration = abs(velocity - p_velocity)

        feature_vector = [x1_change, y1_change, x2_change, y2_change,
                          center_x_change, center_y_change, distance_moved, velocity, acceleration]
        return feature_vector

    def normalize_features(self):
        all_features = [feature for sequence, _ in self.data for feature in sequence]
        all_features = np.array(all_features)
        self.mean = np.mean(all_features, axis=0)
        self.std = np.std(all_features, axis=0)
        for i, (sequence, speed) in enumerate(self.data):
            normalized_sequence = (sequence - self.mean) / (self.std)
            self.data[i] = (normalized_sequence, speed)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        inputs, output = self.data[idx]
        if self.augment:
            inputs = self.apply_augmentation(inputs)
        return torch.tensor(inputs, dtype=torch.float32), torch.tensor(output, dtype=torch.float32)

    def apply_augmentation(self, inputs):
        if random.random() > 0.9:
            inputs = self.add_noise(inputs)
        if random.random() > 0.99:
            inputs = self.time_shift(inputs, shift=random.choice([-1, 1]))
        if random.random() > 0.95:
            inputs = self.scale_features(inputs, scale=random.uniform(0.9, 1.1))
        if random.random() > 0.98:
            inputs = self.mirror_features(inputs)
        return inputs

    def add_noise(self, features, noise_level=0.05):
        noise = np.random.normal(0, noise_level, features.shape)
        return features + noise

    def time_shift(self, features, shift=1):
        if shift > 0:
            return np.vstack([np.zeros((shift, features.shape[1])), features[:-shift]])
        elif shift < 0:
            return np.vstack([features[-shift:], np.zeros((-shift, features.shape[1]))])
        return features

    def scale_features(self, features, scale=1.1):
        return features * scale

    def mirror_features(self, features):
        features_copy = features.copy()
        features_copy[:, [0, 2]] = -features_copy[:, [0, 2]]  # Assume these indices are the x-coordinates
        return features_copy

# %%
import torch

# Check for CUDA
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=0.1)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class SpeedPredictor(nn.Module):
    def __init__(self, sequence_length, feature_size, hidden_dim, output_size):
        super(SpeedPredictor, self).__init__()
        self.embedding = nn.Conv1d(in_channels=feature_size, out_channels=hidden_dim, kernel_size=1)
        self.pos_encoder = PositionalEncoding(hidden_dim)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=hidden_dim, nhead=4, dim_feedforward=hidden_dim * 4, dropout=0.4)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=2)
        self.fc1 = nn.Linear(hidden_dim, 16)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(16, output_size)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.embedding(x)
        x = x.permute(0, 2, 1)
        x = x.permute(1, 0, 2)
        x = self.pos_encoder(x)
        x = self.transformer_encoder(x)
        x = x.permute(1, 0, 2)  # Switch back to (batch, seq_len, features)
        x = x[:, -1, :]  # Only use the last sequence output for prediction
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight)
        nn.init.constant_(m.bias, 0)

# %%
def train_and_validate(model, train_loader, val_loader, criterion, optimizer,scheduler, epochs):
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        # Training
        model.train()
        total_train_loss = 0
        for inputs, speeds in train_loader:
            inputs, speeds = inputs.to(device), speeds.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            outputs = outputs.squeeze()
            if outputs.shape != speeds.shape:
                outputs = outputs[:speeds.size(0)]
            loss = criterion(outputs, speeds)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
        scheduler.step()
        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Validation
        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for inputs, speeds in val_loader:
                inputs, speeds= inputs.to(device), speeds.to(device)
                outputs = model(inputs)
                outputs = outputs.squeeze()

                # if len(outputs.shape) == 1:
                # # Remove the slicing operation if the tensor has a single dimension
                #   outputs = outputs
                # else:
                #   print(outputs.shape)
                #   print(speeds.shape)
                # outputs = outputs[:speeds.size(0)]

                # Adjust the slicing operation if the tensor has multiple dimensions
                  # outputs = outputs[:speeds.size(0)]

                # if outputs.shape != speeds.shape:
                #     print(outputs.shape)
                #     print(speeds.shape)
                #     outputs = outputs[:speeds.size(0)]
                loss = torch.sqrt(criterion(outputs, speeds))
                total_val_loss += loss.item()
        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        if epoch % 10 ==0:
            print(f'Epoch {epoch+1}/{epochs}, MSE training Loss: {avg_train_loss:.4f}, RMSE validation Loss: {avg_val_loss:.4f}')

    return train_losses, val_losses

# %%
import torch
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

train_dataset = SpeedDataset('./Dataset/Train/', sequence_length=15)
test_dataset = SpeedDataset('./Dataset/Test/', sequence_length=15)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Model, Loss, and Optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SpeedPredictor(sequence_length=15, feature_size=9, hidden_dim=128, output_size=1)
model.to(device)
model.apply(init_weights)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Scheduler for learning rate adjustment
scheduler = ExponentialLR(optimizer, gamma=0.9999999999)
train_losses,val_losses = train_and_validate(model, train_loader, test_loader, criterion, optimizer, scheduler, epochs=200)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Epoch 1/200, MSE training Loss: 3468.8279, RMSE validation Loss: 48.6917
# Epoch 2/200, MSE training Loss: 2896.6009, RMSE validation Loss: 45.7251
# Epoch 3/200, MSE training Loss: 2693.9321, RMSE validation Loss: 43.4251
# Epoch 4/200, MSE training Loss: 2494.5026, RMSE validation Loss: 41.1519
# Epoch 5/200, MSE training Loss: 2301.6889, RMSE validation Loss: 38.8556
# Epoch 6/200, MSE training Loss: 2127.9049, RMSE validation Loss: 36.5129
# Epoch 7/200, MSE training Loss: 1961.6477, RMSE validation Loss: 34.1160
# Epoch 8/200, MSE training Loss: 1821.8335, RMSE validation Loss: 31.7813
# Epoch 9/200, MSE training Loss: 1664.9326, RMSE validation Loss: 29.4559
# Epoch 10/200, MSE training Loss: 1513.3319, RMSE validation Loss: 27.3151
# Epoch 11/200, MSE training Loss: 1379.9339, RMSE validation Loss: 25.3868
# Epoch 12/200, MSE training Loss: 1216.8689, RMSE validation Loss: 23.5790
# Epoch 13/200, MSE training Loss: 1138.2469, RMSE validation Loss: 22.2243
# Epoch 14/200, MSE training Loss: 1088.3435, RMSE validation Loss: 21.0764
# Epoch 15/200, MSE training Loss: 1064.7378, RMSE validation Loss: 20.2132
# Epoch 16/200, MSE training Loss: 1001.3260, RMSE validation Loss: 19.6997
# Epoch 17/200, MSE training Loss: 974.1327, RMSE validation Loss: 19.3385
# Epoch 18/200, MSE training Loss: 940.1185, RMSE validation Loss: 19.0388
# Epoch 19/200, MSE training Loss: 942.9724, RMSE validation Loss: 18.7164
# Epoch 20/200, MSE training Loss: 863.0582, RMSE validation Loss: 17.5245
# Epoch 21/200, MSE training Loss: 848.4159, RMSE validation Loss: 16.1087
# Epoch 22/200, MSE training Loss: 787.8205, RMSE validation Loss: 14.4818
# Epoch 23/200, MSE training Loss: 756.3447, RMSE validation Loss: 14.5504
# Epoch 24/200, MSE training Loss: 695.7249, RMSE validation Loss: 14.9784
# Epoch 25/200, MSE training Loss: 726.2677, RMSE validation Loss: 13.1190
# Epoch 26/200, MSE training Loss: 683.2258, RMSE validation Loss: 12.6447
# Epoch 27/200, MSE training Loss: 657.3063, RMSE validation Loss: 12.1328
# Epoch 28/200, MSE training Loss: 613.7506, RMSE validation Loss: 11.9058
# Epoch 29/200, MSE training Loss: 634.3498, RMSE validation Loss: 11.2805
# Epoch 30/200, MSE training Loss: 634.6341, RMSE validation Loss: 12.1213
# Epoch 31/200, MSE training Loss: 615.5130, RMSE validation Loss: 9.9963
# Epoch 32/200, MSE training Loss: 598.1593, RMSE validation Loss: 10.3567
# Epoch 33/200, MSE training Loss: 588.9746, RMSE validation Loss: 10.5888
# Epoch 34/200, MSE training Loss: 598.0369, RMSE validation Loss: 9.5569
# Epoch 35/200, MSE training Loss: 587.4413, RMSE validation Loss: 9.2125
# Epoch 36/200, MSE training Loss: 588.3541, RMSE validation Loss: 10.8953
# Epoch 37/200, MSE training Loss: 592.8051, RMSE validation Loss: 8.9764
# Epoch 38/200, MSE training Loss: 579.1647, RMSE validation Loss: 10.3990
# Epoch 39/200, MSE training Loss: 565.5020, RMSE validation Loss: 8.7244
# Epoch 40/200, MSE training Loss: 573.4414, RMSE validation Loss: 9.1693
# Epoch 41/200, MSE training Loss: 580.1695, RMSE validation Loss: 9.4038
# Epoch 42/200, MSE training Loss: 568.4802, RMSE validation Loss: 9.2544
# Epoch 43/200, MSE training Loss: 571.8959, RMSE validation Loss: 8.9624
# Epoch 44/200, MSE training Loss: 567.3587, RMSE validation Loss: 10.1864
# Epoch 45/200, MSE training Loss: 569.9338, RMSE validation Loss: 8.3901
# Epoch 46/200, MSE training Loss: 537.2323, RMSE validation Loss: 8.2593
# Epoch 47/200, MSE training Loss: 556.6269, RMSE validation Loss: 9.9194
# Epoch 48/200, MSE training Loss: 536.1982, RMSE validation Loss: 8.7510
# Epoch 49/200, MSE training Loss: 550.4234, RMSE validation Loss: 8.8451
# Epoch 50/200, MSE training Loss: 585.3196, RMSE validation Loss: 9.0991
# Epoch 51/200, MSE training Loss: 559.6828, RMSE validation Loss: 8.2195
# Epoch 52/200, MSE training Loss: 574.1157, RMSE validation Loss: 8.1548
# Epoch 53/200, MSE training Loss: 534.4530, RMSE validation Loss: 7.9917
# Epoch 54/200, MSE training Loss: 545.6384, RMSE validation Loss: 7.8784
# Epoch 55/200, MSE training Loss: 538.1736, RMSE validation Loss: 8.7164
# Epoch 56/200, MSE training Loss: 558.2114, RMSE validation Loss: 7.4771
# Epoch 57/200, MSE training Loss: 536.0901, RMSE validation Loss: 8.6250
# Epoch 58/200, MSE training Loss: 550.1592, RMSE validation Loss: 9.7136
# Epoch 59/200, MSE training Loss: 552.9651, RMSE validation Loss: 7.3075
# Epoch 60/200, MSE training Loss: 558.1563, RMSE validation Loss: 8.6640
# Epoch 61/200, MSE training Loss: 574.0470, RMSE validation Loss: 9.9025
# Epoch 62/200, MSE training Loss: 531.1019, RMSE validation Loss: 7.8149
# Epoch 63/200, MSE training Loss: 535.9563, RMSE validation Loss: 7.5007
# Epoch 64/200, MSE training Loss: 554.6016, RMSE validation Loss: 7.6939
# Epoch 65/200, MSE training Loss: 543.8536, RMSE validation Loss: 9.4451
# Epoch 66/200, MSE training Loss: 516.1363, RMSE validation Loss: 8.4567
# Epoch 67/200, MSE training Loss: 542.5161, RMSE validation Loss: 9.5187
# Epoch 68/200, MSE training Loss: 535.3734, RMSE validation Loss: 8.3567
# Epoch 69/200, MSE training Loss: 522.9962, RMSE validation Loss: 7.8361
# Epoch 70/200, MSE training Loss: 496.9886, RMSE validation Loss: 7.9230
# Epoch 71/200, MSE training Loss: 542.7587, RMSE validation Loss: 10.3617
# Epoch 72/200, MSE training Loss: 530.0871, RMSE validation Loss: 8.0930
# Epoch 73/200, MSE training Loss: 524.6241, RMSE validation Loss: 8.4324
# Epoch 74/200, MSE training Loss: 500.9663, RMSE validation Loss: 7.1738
# Epoch 75/200, MSE training Loss: 538.0797, RMSE validation Loss: 9.1790
# Epoch 76/200, MSE training Loss: 504.1603, RMSE validation Loss: 7.3921
# Epoch 77/200, MSE training Loss: 495.0695, RMSE validation Loss: 8.4233
# Epoch 78/200, MSE training Loss: 517.1336, RMSE validation Loss: 9.3809
# Epoch 79/200, MSE training Loss: 506.3574, RMSE validation Loss: 9.9999
# Epoch 80/200, MSE training Loss: 503.6093, RMSE validation Loss: 11.5808
# Epoch 81/200, MSE training Loss: 513.8009, RMSE validation Loss: 9.8337
# Epoch 82/200, MSE training Loss: 481.1514, RMSE validation Loss: 12.2307
# Epoch 83/200, MSE training Loss: 496.7378, RMSE validation Loss: 7.8199
# Epoch 84/200, MSE training Loss: 485.5611, RMSE validation Loss: 6.9893
# Epoch 85/200, MSE training Loss: 493.8989, RMSE validation Loss: 7.2716
# Epoch 86/200, MSE training Loss: 500.0852, RMSE validation Loss: 10.1887
# Epoch 87/200, MSE training Loss: 494.2439, RMSE validation Loss: 10.6965
# Epoch 88/200, MSE training Loss: 499.9094, RMSE validation Loss: 10.6181
# Epoch 89/200, MSE training Loss: 538.6509, RMSE validation Loss: 9.0085
# Epoch 90/200, MSE training Loss: 479.5559, RMSE validation Loss: 7.9784
# Epoch 91/200, MSE training Loss: 482.2761, RMSE validation Loss: 9.2038
# Epoch 92/200, MSE training Loss: 494.5337, RMSE validation Loss: 8.2243
# Epoch 93/200, MSE training Loss: 479.5841, RMSE validation Loss: 9.0312
# Epoch 94/200, MSE training Loss: 484.8554, RMSE validation Loss: 7.9216
# Epoch 95/200, MSE training Loss: 481.2507, RMSE validation Loss: 9.6929
# Epoch 96/200, MSE training Loss: 487.2694, RMSE validation Loss: 7.9314
# Epoch 97/200, MSE training Loss: 470.7376, RMSE validation Loss: 8.1239
# Epoch 98/200, MSE training Loss: 495.5150, RMSE validation Loss: 9.7175
# Epoch 99/200, MSE training Loss: 474.5953, RMSE validation Loss: 7.0024
# Epoch 100/200, MSE training Loss: 470.4243, RMSE validation Loss: 8.4306
# Epoch 101/200, MSE training Loss: 468.3756, RMSE validation Loss: 7.4304
# Epoch 102/200, MSE training Loss: 470.5345, RMSE validation Loss: 9.6787
# Epoch 103/200, MSE training Loss: 487.4707, RMSE validation Loss: 8.7736
# Epoch 104/200, MSE training Loss: 470.9626, RMSE validation Loss: 7.5669
# Epoch 105/200, MSE training Loss: 483.3184, RMSE validation Loss: 9.4299
# Epoch 106/200, MSE training Loss: 476.7711, RMSE validation Loss: 8.8037
# Epoch 107/200, MSE training Loss: 477.4516, RMSE validation Loss: 8.2987
# Epoch 108/200, MSE training Loss: 489.0470, RMSE validation Loss: 7.6870
# Epoch 109/200, MSE training Loss: 475.4972, RMSE validation Loss: 8.2997
# Epoch 110/200, MSE training Loss: 494.7979, RMSE validation Loss: 10.0787
# Epoch 111/200, MSE training Loss: 483.5739, RMSE validation Loss: 11.1071
# Epoch 112/200, MSE training Loss: 461.6299, RMSE validation Loss: 7.0191
# Epoch 113/200, MSE training Loss: 480.6245, RMSE validation Loss: 7.1711
# Epoch 114/200, MSE training Loss: 473.2395, RMSE validation Loss: 11.0093
# Epoch 115/200, MSE training Loss: 489.7155, RMSE validation Loss: 8.9642
# Epoch 116/200, MSE training Loss: 498.0454, RMSE validation Loss: 8.0851
# Epoch 117/200, MSE training Loss: 465.9429, RMSE validation Loss: 7.0444
# Epoch 118/200, MSE training Loss: 481.1145, RMSE validation Loss: 9.5683
# Epoch 119/200, MSE training Loss: 492.6510, RMSE validation Loss: 9.4246
# Epoch 120/200, MSE training Loss: 462.9128, RMSE validation Loss: 10.0666
# Epoch 121/200, MSE training Loss: 468.4938, RMSE validation Loss: 8.9955
# Epoch 122/200, MSE training Loss: 478.5872, RMSE validation Loss: 8.3418
# Epoch 123/200, MSE training Loss: 473.0627, RMSE validation Loss: 9.1003
# Epoch 124/200, MSE training Loss: 466.8681, RMSE validation Loss: 8.1188
# Epoch 125/200, MSE training Loss: 490.3519, RMSE validation Loss: 7.4403
# Epoch 126/200, MSE training Loss: 463.1374, RMSE validation Loss: 8.1033
# Epoch 127/200, MSE training Loss: 482.5826, RMSE validation Loss: 8.3984
# Epoch 128/200, MSE training Loss: 477.5086, RMSE validation Loss: 7.7984
# Epoch 129/200, MSE training Loss: 473.1882, RMSE validation Loss: 9.3872
# Epoch 130/200, MSE training Loss: 454.6582, RMSE validation Loss: 8.6277
# Epoch 131/200, MSE training Loss: 451.6978, RMSE validation Loss: 7.0149
# Epoch 132/200, MSE training Loss: 460.5388, RMSE validation Loss: 8.9619
# Epoch 133/200, MSE training Loss: 486.7494, RMSE validation Loss: 10.3883
# Epoch 134/200, MSE training Loss: 470.7588, RMSE validation Loss: 8.7261
# Epoch 135/200, MSE training Loss: 471.2892, RMSE validation Loss: 6.8925
# Epoch 136/200, MSE training Loss: 498.7437, RMSE validation Loss: 7.4436
# Epoch 137/200, MSE training Loss: 472.8887, RMSE validation Loss: 9.1955
# Epoch 138/200, MSE training Loss: 457.5473, RMSE validation Loss: 7.5788
# Epoch 139/200, MSE training Loss: 485.2507, RMSE validation Loss: 7.8429
# Epoch 140/200, MSE training Loss: 463.6087, RMSE validation Loss: 7.7197
# Epoch 141/200, MSE training Loss: 470.5952, RMSE validation Loss: 8.0117
# Epoch 142/200, MSE training Loss: 464.7658, RMSE validation Loss: 10.6832
# Epoch 143/200, MSE training Loss: 498.0099, RMSE validation Loss: 6.9876
# Epoch 144/200, MSE training Loss: 486.6237, RMSE validation Loss: 6.8125
# Epoch 145/200, MSE training Loss: 476.8586, RMSE validation Loss: 8.0420
# Epoch 146/200, MSE training Loss: 474.6804, RMSE validation Loss: 8.2706
# Epoch 147/200, MSE training Loss: 468.5600, RMSE validation Loss: 9.1031
# Epoch 148/200, MSE training Loss: 467.8384, RMSE validation Loss: 8.7373
# Epoch 149/200, MSE training Loss: 467.6561, RMSE validation Loss: 9.7538
# Epoch 150/200, MSE training Loss: 463.9572, RMSE validation Loss: 9.6309
# Epoch 151/200, MSE training Loss: 478.5284, RMSE validation Loss: 8.5154
# Epoch 152/200, MSE training Loss: 446.1487, RMSE validation Loss: 9.9139
# Epoch 153/200, MSE training Loss: 460.7035, RMSE validation Loss: 7.2481
# Epoch 154/200, MSE training Loss: 475.3579, RMSE validation Loss: 10.5464
# Epoch 155/200, MSE training Loss: 473.0377, RMSE validation Loss: 12.8887
# Epoch 156/200, MSE training Loss: 474.0847, RMSE validation Loss: 12.3736
# Epoch 157/200, MSE training Loss: 501.1704, RMSE validation Loss: 7.6104
# Epoch 158/200, MSE training Loss: 469.1807, RMSE validation Loss: 10.1276
# Epoch 159/200, MSE training Loss: 461.7453, RMSE validation Loss: 9.7007
# Epoch 160/200, MSE training Loss: 461.5291, RMSE validation Loss: 7.0603
# Epoch 161/200, MSE training Loss: 462.2052, RMSE validation Loss: 10.1395
# Epoch 162/200, MSE training Loss: 473.9275, RMSE validation Loss: 9.1088
# Epoch 163/200, MSE training Loss: 471.0870, RMSE validation Loss: 10.5738
# Epoch 164/200, MSE training Loss: 487.3498, RMSE validation Loss: 8.7112
# Epoch 165/200, MSE training Loss: 467.0459, RMSE validation Loss: 11.9312
# Epoch 166/200, MSE training Loss: 459.6413, RMSE validation Loss: 9.5735
# Epoch 167/200, MSE training Loss: 452.3142, RMSE validation Loss: 8.8114
# Epoch 168/200, MSE training Loss: 469.4301, RMSE validation Loss: 11.4962
# Epoch 169/200, MSE training Loss: 471.5879, RMSE validation Loss: 7.6574
# Epoch 170/200, MSE training Loss: 474.2316, RMSE validation Loss: 9.2015
# Epoch 171/200, MSE training Loss: 458.9633, RMSE validation Loss: 7.0788
# Epoch 172/200, MSE training Loss: 483.4264, RMSE validation Loss: 7.2847
# Epoch 173/200, MSE training Loss: 448.7725, RMSE validation Loss: 8.3822
# Epoch 174/200, MSE training Loss: 466.4444, RMSE validation Loss: 8.7073
# Epoch 175/200, MSE training Loss: 462.2878, RMSE validation Loss: 9.9318
# Epoch 176/200, MSE training Loss: 464.4605, RMSE validation Loss: 7.7899
# Epoch 177/200, MSE training Loss: 457.5028, RMSE validation Loss: 6.8017
# Epoch 178/200, MSE training Loss: 447.7936, RMSE validation Loss: 10.3082
# Epoch 179/200, MSE training Loss: 461.8434, RMSE validation Loss: 11.3136
# Epoch 180/200, MSE training Loss: 475.2588, RMSE validation Loss: 7.0466
# Epoch 181/200, MSE training Loss: 454.9182, RMSE validation Loss: 9.0946
# Epoch 182/200, MSE training Loss: 451.5789, RMSE validation Loss: 9.9614
# Epoch 183/200, MSE training Loss: 459.6746, RMSE validation Loss: 9.0083
# Epoch 184/200, MSE training Loss: 471.9462, RMSE validation Loss: 9.4033
# Epoch 185/200, MSE training Loss: 475.7840, RMSE validation Loss: 12.1826
# Epoch 186/200, MSE training Loss: 488.8503, RMSE validation Loss: 8.8066
# Epoch 187/200, MSE training Loss: 456.0730, RMSE validation Loss: 10.2365
# Epoch 188/200, MSE training Loss: 481.1897, RMSE validation Loss: 9.4323
# Epoch 189/200, MSE training Loss: 476.0291, RMSE validation Loss: 9.6779
# Epoch 190/200, MSE training Loss: 464.6702, RMSE validation Loss: 7.0497
# Epoch 191/200, MSE training Loss: 472.2695, RMSE validation Loss: 10.1266
# Epoch 192/200, MSE training Loss: 465.3549, RMSE validation Loss: 9.4432
# Epoch 193/200, MSE training Loss: 473.1579, RMSE validation Loss: 9.0333
# Epoch 194/200, MSE training Loss: 455.7757, RMSE validation Loss: 8.7200
# Epoch 195/200, MSE training Loss: 458.2302, RMSE validation Loss: 7.6434
# Epoch 196/200, MSE training Loss: 453.4370, RMSE validation Loss: 8.8674
# Epoch 197/200, MSE training Loss: 447.5608, RMSE validation Loss: 10.0844
# Epoch 198/200, MSE training Loss: 447.3549, RMSE validation Loss: 9.6040
# Epoch 199/200, MSE training Loss: 466.8132, RMSE validation Loss: 11.4005
# Epoch 200/200, MSE training Loss: 502.4720, RMSE validation Loss: 7.3327

# %%
# Plotting training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(range(1, 200+1), train_losses, label='Training Loss')
plt.plot(range(1, 200+1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Transformer Training and Validation Loss')
plt.legend()
plt.show()

# %%
torch.save(model, 'Transformer_Regression_150.pth')

# %%
# Load the entire model
model = torch.load('Transformer_Regression_150.pth').to(device)
model.eval()  # Set the model to evaluation mode
# Out:
# SpeedPredictor(
#   (embedding): Conv1d(9, 128, kernel_size=(1,), stride=(1,))
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder_layer): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#     )
#     (linear1): Linear(in_features=128, out_features=512, bias=True)
#     (dropout): Dropout(p=0.4, inplace=False)
#     (linear2): Linear(in_features=512, out_features=128, bias=True)
#     (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.4, inplace=False)
#     (dropout2): Dropout(p=0.4, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#     )
#   )
#   (fc1): Linear(in_features=128, out_features=16, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
import random
def predict_and_compare(model, test_loader):
    model.eval()  # Ensure the model is in evaluation mode
    predictions = []
    actuals = []
    total_loss = 0
    with torch.no_grad():  # No need to track gradients
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            print(outputs.shape)
            print(len(inputs))
            predictions.extend(outputs.squeeze().tolist())
            actuals.extend(targets.tolist())
            loss = torch.sqrt(criterion(outputs, targets))
            if outputs.shape != targets.shape:
                outputs = outputs[:targets.size(0)]
            total_loss += loss.item()
    return predictions, actuals, total_loss/len(test_loader)

test_dataset = SpeedDataset('./Dataset/Test/', sequence_length=15)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
predictions, actuals, loss = predict_and_compare(model, test_loader)

def print_random_predictions(predictions, actuals, num_samples=30):
    if len(predictions) < num_samples:
        num_samples = len(predictions)  # Adjust sample size if predictions are fewer than requested

    # Get random sample indices
    sample_indices = random.sample(range(len(predictions)), num_samples)

    # Print the randomly selected predictions and their actual values
    for idx in sample_indices:
        print(f"Predicted: {predictions[idx]:.4f}, Actual: {actuals[idx]:.4f}")

# Assuming you have already executed the predict_and_compare function
# predictions, actuals = predict_and_compare(model, val_loader)

# Now print randomly selected 30 predictions and their actual values
print_random_predictions(predictions, actuals, 50)
print(loss)
# Out:
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([32, 1])
# 32
# torch.Size([20, 1])
# 20
# Predicted: 59.9417, Actual: 50.0000
# Predicted: 63.8401, Actual: 61.0000
# Predicted: 45.6735, Actual: 43.0000
# Predicted: 83.3448, Actual: 84.0000
# Predicted: 52.9951, Actual: 64.0000
# Predicted: 58.1813, Actual: 47.0000
# Predicted: 45.9721, Actual: 38.0000
# Predicted: 89.6333, Actual: 86.0000
# Predicted: 34.4784, Actual: 30.0000
# Predicted: 62.2495, Actual: 64.0000
# Predicted: 81.9183, Actual: 54.0000
# Predicted: 56.8234, Actual: 51.0000
# Predicted: 95.6317, Actual: 97.0000
# Predicted: 74.0630, Actual: 70.0000
# Predicted: 64.7600, Actual: 57.0000
# Predicted: 49.0898, Actual: 54.0000
# Predicted: 34.5092, Actual: 30.0000
# Predicted: 42.7644, Actual: 44.0000
# Predicted: 56.6835, Actual: 49.0000
# Predicted: 63.8448, Actual: 61.0000
# Predicted: 35.0959, Actual: 30.0000
# Predicted: 94.9405, Actual: 100.0000
# Predicted: 44.5297, Actual: 44.0000
# Predicted: 88.3965, Actual: 84.0000
# Predicted: 33.1373, Actual: 35.0000
# Predicted: 50.4213, Actual: 47.0000
# Predicted: 53.8971, Actual: 49.0000
# Predicted: 60.6119, Actual: 57.0000
# Predicted: 36.3502, Actual: 35.0000
# Predicted: 55.4915, Actual: 47.0000
# Predicted: 65.1336, Actual: 61.0000
# Predicted: 77.4603, Actual: 70.0000
# Predicted: 37.0085, Actual: 30.0000
# Predicted: 42.9751, Actual: 47.0000
# Predicted: 44.3190, Actual: 43.0000
# Predicted: 75.9493, Actual: 64.0000
# Predicted: 79.3938, Actual: 68.0000
# Predicted: 55.7236, Actual: 54.0000
# Predicted: 62.8335, Actual: 57.0000
# Predicted: 60.6594, Actual: 49.0000
# Predicted: 91.6243, Actual: 82.0000
# Predicted: 36.5669, Actual: 38.0000
# Predicted: 70.2911, Actual: 74.0000
# Predicted: 57.2178, Actual: 51.0000
# Predicted: 65.0573, Actual: 75.0000
# Predicted: 51.3593, Actual: 47.0000
# Predicted: 80.9775, Actual: 86.0000
# Predicted: 55.5989, Actual: 51.0000
# Predicted: 63.7291, Actual: 64.0000
# Predicted: 54.7734, Actual: 51.0000
# 18.587572479248045
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([20])) that is different to the input size (torch.Size([20, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
